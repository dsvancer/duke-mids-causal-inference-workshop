# %% [markdown]
# # Welcome to the Workshop
#
# <center>
# <img
#   src="assets/mids_logo_white.png"
#   alt="MIDS Logo"
#   style="width:400px;height:auto;"
# >

# %% [markdown]
# ## About the Workshop
# Summary here
#
# ## Applied Coding Sessions
# This workshop includes several applied coding sessions where we demonstrate techniques with Python.
#
# We will cover the following high-level tops:
# - Topic 1
# - Topic 2
#
#
# Navigate to the `notebooks` folder to get started and code along with us!
